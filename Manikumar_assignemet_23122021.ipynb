# %% [raw]
# 1 . you have to write a fun which will take string and return a len of
# it without using a inbuilt fun len
# 2 . write a fun which will be able to print an index of all premitive element which you will pass
# 3 . Write a fun which will take input as a dict and give me out as a list of all the values
# even in case of 2 level nesting it should work .
# 4 . write a fun which will take another function as an input and return me an output
# 5. write a function whihc will take multiple list as a input and give me concatnation of all the element as
# and output
# 6 . write a function which will be able to take a list as an input return an index of each element
# like a inbuilt index function but even if we have repetative element it should return index
# 7 . Write a function which will whould return list of all the file name from a directory .
# 8  . write a function which will be able to show your system configuration .
# 9 . write a function which will be able to show date and time  .
# 10 . write a function whihc will be able to read a image file and show it to you .
# 11 . write a function which can read video file and play for you .
# 12  . write a function whihc can move a file from one directory to another directory .
# 13 . write a function which will be able to shutdonw your system .
# 14 . write a function whihc will be able to access your mail .
# 15 . write a func bywhcih i can send a mail to anyone
# 16. write a func to read a complete PDf file .
# 17. write a function to read a word file .
# 18 . write a function which can help you to filter only word file from a directory .
# 19 . write a function by which you can print an ip address of your system .
# 20 . write a function by which you will be able to append two PDF files .

# %%
#1.you have to write a fun which will take string and return a len of it without using a inbuilt fun len

def test1(x):
    count=0
    for i in x:
        count=count+1
    return count    
test1('manikumar')
# Out:
# 9

# %%
#2 . write a fun which will be able to print an index of all premitive element which you will pass 
def test2(lst):
    for i in range(len(lst)):
        print(f"index of {lst[i]} is {i}"," and type is",type(lst[i]))
test2([22,'python',[1,2,3,4],(4,'class'),3+2j])
# Out:
# index of 22 is 0  and type is <class 'int'>
# index of python is 1  and type is <class 'str'>
# index of [1, 2, 3, 4] is 2  and type is <class 'list'>
# index of (4, 'class') is 3  and type is <class 'tuple'>
# index of (3+2j) is 4  and type is <class 'complex'>

# %%
#3 . Write a fun which will take input as a dict and give me out as a list of all the values even in case of 2 level nesting it should work
l=[]
def test3(x):
    if type(x)==dict:
        for i in x.values():
            if type(i)==int:
                l.append(i)  
            elif type(i)==list:
                l.extend(i)
            elif type(i)==tuple:   
                l.extend(i)
            elif type(i)==str:
                l.append(i)
            elif type(i)==dict:
                b=test3(i)
    return l                
                
    
           
test3({'a':0,'b':[1,2,3],'c':(4,5,6),'key':{'key2':1000,'key4':{'key5':'mmmmm'}},'key100':('dog','cat')}) 
#test3({'key':{'key2':10000}})
# Out:
# [0, 1, 2, 3, 4, 5, 6, 1000, 'mmmmm', 'dog', 'cat']

# %%
#3 . Write a fun which will take input as a dict and give me out as a list of all the values even in case of 2 level nesting it should work
def test3(d):
    lst=[]
    test3b(d,lst)
    return lst
def test3b(d3,lst):
    if type(d3)==dict:
        for i in d3.values():
            if type(i)==dict:
                test3b(i,lst)
            elif type(i)==int:
                lst.append(i)
            elif type(i)==list:
                lst.extend(i)
            elif type(i)==tuple:
                lst.extend(i)
    return lst   
test3({'a':0,'b':[1,2,3],'c':(4,5,6),'key':{'key2':10000},'key100':('dog','cat')})
# Out:
# [0, 1, 2, 3, 4, 5, 6, 10000, 'dog', 'cat']

# %%
#4 . write a fun which will take another function as an input and return me an output 
def test4(x):
    if type(x)==str:
        return x
def test4a(y):
    return y.upper()

z=test4a(test4('mani kumar'))
print(z)

# %%
#5.write a function whihc will take multiple list as a input and give me concatnation of all the element as and output 
def test5(*args):
    l=[]
    for i in args:
        if type(i)==list:
            l=l+i
    return l

test5([1,2,3],[4,5,6],[7,8,9])
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
#6 . write a function which will be able to take a list as an input return an index of each element 
def test6(x):
    for i in range(len(x)):
        print("Index of",i,"is",x[i])
test6([1,3,"python","ineuron",4,4,4,4,4])
# Out:
# Index of 0 is 1
# Index of 1 is 3
# Index of 2 is python
# Index of 3 is ineuron
# Index of 4 is 4
# Index of 5 is 4
# Index of 6 is 4
# Index of 7 is 4
# Index of 8 is 4

# %%
#7 . Write a function which will whould return list of all the file name from a directory . 
def test7(path):
    path=input()
    import os
    y=os.listdir(path)
    return y
test7('path')
# Out:
# F:\Mani kumar\py\RE
# ['re1.py', 're2.py', 're3.py', 're4.py', 're5.py', 're6.py', 're7.py']

# %%
#8.write a function which will be able to show your system configuration.
def test8():
    import platform as pl
    print('system:',pl.system())
    print('Machine:',pl.machine())
    print('Hostname:',pl.node())
    print('processor:',pl.processor())
    print('Release:',pl.release())
    print('Version:',pl.version())
    sys_data=pl.uname()
    return sys_data
test8()
# Out:
# system: Windows
# Machine: AMD64
# Hostname: ManiKumar
# processor: Intel64 Family 6 Model 61 Stepping 4, GenuineIntel
# Release: 10
# Version: 10.0.19043
# uname_result(system='Windows', node='ManiKumar', release='10', version='10.0.19043', machine='AMD64')

# %%
#9.write a function which will be able to show date and time .
from datetime import *
def test9():
    today=datetime.now()
    date_time=today.strftime("%d/%m/%y %H:%M:%S")
    print("Date and Time is:",date_time)
    return
test9()
# Out:
# Date and Time is: 16/01/22 15:33:28

# %%
#9 . write a function which will be able to show date and time .(Method 2) 

from datetime import datetime

# datetime object containing current date and time
now = datetime.now()
 
print("now =", now)

# dd/mm/YY H:M:S
dt_string = now.strftime("%d/%m/%Y %H:%M:%S")
print("date and time =", dt_string)
# Out:
# now = 2022-01-17 19:48:22.262746
# date and time = 17/01/2022 19:48:22

# %%
#10 . write a function whihc will be able to read a image file and show it to you .
image=input("Enter the image file name:")
def test10(image):
    #import cv2
    from PIL import Image
    #img=cv2.imread(image)
    #cv2.imshow('The Image is:',img)
    img=Image.open(image,'r')
    show=display(img)
    return show
test10(image)
# Out:
# Enter the image file name:ineuron.png
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=292x181 at 0x27963C99250>

# %%
#11.write a function which can read video file and play for you . 
import numpy as np
import cv2
def test11(filename):
    capture=cv2.VideoCapture('filename')
    while (True):
        ret,frame=capture.read()
        if ret==True:
            cv2.imshow('output',frame)
            if (cv2.waitKey(1) & 0xFF==ord('q')):
                break
        else:
            break
    capture.release()
    cv2.destroyAllWindows()
    return
test11('test11.mp4')

# %%
#12 .write a function whihc can move a file from one directory to another directory . 
def test12(s_path,d_path):
    import os
    import shutil
    f=os.listdir(s_path)
    
    for i in f:
        print(i)
    shutil.move(s_path,d_path)
    return
s_path=input("Enter the source path:")
d_path=input("Enter the desitnation path:")
test12(s_path,d_path)
#C:\Users\Admin\1.Ineuron\23 Dec 2021\Ineuron\Source_folder
#C:\Users\Admin\1.Ineuron\23 Dec 2021\Ineuron\destination_folder
# Out:
# Enter the source path:C:\Users\Admin\1.Ineuron\23 Dec 2021\Ineuron\Source_folder
# Enter the desitnation path:C:\Users\Admin\1.Ineuron\23 Dec 2021\Ineuron\destination_folder
# test1.txt
# test2.txt

# %%
#13 . write a function which will be able to shutdonw your system . 
def test13():
    check=input("Do you want to shut down yous PC? (Yes/No):")
    if check=='No':
        print("Not shutdown")
        exit()
    else:
        os.system("shutdown /s /t 1")
test13()
# Out:
# Do you want to shut down yous PC? (Yes/No):No
# Not shutdown

# %%
#14 . write a function whihc will be able to access your mail . 
import easyimap as e
def test14(username,pwd):
    server=e.connect('imap.gmail.com',username,pwd)
    email=server.mail(server.listids()[0])
    print('Sender:\n',email.from_addr)
    print('\nTitle:\n',email.title)
    print('\nBody:\n',email.body)
    print('\nAttachments:\n',email.attachements)
    return
def test14(username,pwd):

# %%
#15 . write a func bywhcih i can send a mail to anyone 
import smtplib as s
def test15(username,password,sentusername,msg):
    server=s.SMTP('smtp.gmail.com',587)
    server.starttls()
    server.login(username,password)
    server.sendmail(username,sentusername,msg)
    server.close()
    print('Mail Sent')
    return
#username=input()
#password=input()
#sentusername=input()
#msg=input()
test15(username,password,sentusername,msg)

# %%
#16. write a func to read a complete PDf file . 
def test16(file_name):
    import PyPDF2
    #file_name=input('Enter file_name:')
    #c=int(input('Enter page number:'))
    pdf_file_obj=open(file_name,'rb') # pdf file object
    pdf_reader=PyPDF2.PdfFileReader(pdf_file_obj) #pdf reader object
    print(pdf_reader.numPages)# printing no. of pages
    #page_obj=pdf_reader.getPage(pagenumber)
    for i in range(pdf_reader.numPages):
        print(pdf_reader.getPage(i))
    return 
file_name=input('Enter file_name:')
#pagenumber=int(input('Enter page number:'))
test16(file_name)
#example.pdf
# Out:
# Enter file_name:example.pdf
# 20
# {'/Type': '/Page', '/MediaBox': [0, 0, 612, 792], '/Rotate': 0, '/Parent': IndirectObject(3, 0), '/Resources': {'/ProcSet': ['/PDF', '/Text'], '/ExtGState': IndirectObject(14, 0), '/Font': IndirectObject(15, 0)}, '/Contents': IndirectObject(5, 0)}
# {'/Type': '/Page', '/MediaBox': [0, 0, 612, 792], '/Rotate': 0, '/Parent': IndirectObject(3, 0), '/Resources': {'/ProcSet': ['/PDF', '/Text'], '/ExtGState': IndirectObject(21, 0), '/Font': IndirectObject(22, 0)}, '/Contents': IndirectObject(17, 0)}
# {'/Type': '/Page', '/MediaBox': [0, 0, 612, 792], '/Rotate': 0, '/Parent': IndirectObject(3, 0), '/Resources': {'/ProcSet': ['/PDF', '/ImageB', '/Text'], '/ExtGState': IndirectObject(27, 0), '/XObject': IndirectObject(28, 0), '/Font': IndirectObject(29, 0)}, '/Contents': IndirectObject(24, 0)}
# ...

# %%
#17.write a function to read a word file.
import os
def test17(file_path,file_name):
    if file_name.endswith('doc'):
        f=open(file_name,'r')
        readd=f.readlines()
        for i in readd:
            print(i)
        #print(readd)
    return    
file_path=input("Enter file path:")
file_name=input("Enter file name:")
test17(file_path,file_name)
# Out:
# Enter file path:C:\\Users\\Admin\\1.Ineuron\\23 Dec 2021
# Enter file name:check17.doc
# first line
#
# second line
#
# third line

# %%
#17.write a function to read a word file.#################### method 2
def test17_1(file_path,file_name):
    file_path=input("Enter file path:")
    file_name=input("Enter the file name:")
    file=os.path.join(file_path,file_name)
    f=open(file+'.doc','r')
    read=f.readlines()
    for i in read:
        print(i)
    print('\r')
    return
test17_1('C:\\Users\\Admin\\1.Ineuron\\23 Dec 2021',test17)
# Out:
# Enter file path:C:\\Users\\Admin\\1.Ineuron\\23 Dec 2021
# Enter the file name:check17
# first line
#
# second line
#
# third line

# %%
pwd()
# Out:
# 'C:\\Users\\Admin\\1.Ineuron\\23 Dec 2021'

# %%
#18.write a function which can help you to filter only word file from a directory
def test18(file_path):
    import os
    file_path=input("Enter file path:")
    path=os.listdir(file_path)
    for i in path:
        if i.endswith('doc'):
            print(i)
        #else:
            #print('It is not a word file,please give correct file')
    return
#file_path='C:\\Users\\Admin\\1.Ineuron\\23 Dec 2021'
test18(file_path)
# Out:
# Enter file path:C:\\Users\\Admin\\1.Ineuron\\23 Dec 2021
# check17.doc
# test171.doc

# %%
#19 . write a function by which you can print an ip address of your system . 
import socket
def test19():
    hostname=socket.gethostname()
    ipaddress=socket.gethostbyname(hostname)
    print("your computer name is"+ hostname)
    print("your ipaddress is"  + ipaddress)
    return
test19()
# Out:
# your computer name isManiKumar
# your ipaddress is169.254.88.241

# %%
#20 . write a function by which you will be able to append two PDF files.
import PyPDF2
import os
def test20(file_path,mergefilename):
    #import PyPDF2
    #import os
    filemerger=PyPDF2.PdfFileMerger()
    #for i in os.listdir(file_path):
    #if i.endswith('pdf'):
    for i in file_path:
        filemerger.append(open(i,'rb'))
    #new_file=os.path.join(file_path,mergefilename)
    f=open(mergefilename,'wb')
    filemerger.write(f) 
    filemerger.close()
    return
file_path=['example1.pdf','example2.pdf']
mergefilename='cccccccccccc'
test20(file_path,mergefilename)
